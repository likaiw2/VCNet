# %%
import evaluation
import numpy as np

def get_mae(im1,im2):
    data_range=255.0
    # 归一化到指定大小 0 - data_range
    data1 = ((im1-np.min(im1))/(np.max(im1)-np.min(im1)))*data_range
    data2 = ((im2-np.min(im2))/(np.max(im2)-np.min(im2)))*data_range
    
    mse = abs(data1 - data2).mean()
    return mse

def get_psnr(im1, im2):
    data_range=255.0
    # 归一化到指定大小 0 - data_range
    data1 = ((im1-np.min(im1))/(np.max(im1)-np.min(im1)))*data_range
    data2 = ((im2-np.min(im2))/(np.max(im2)-np.min(im2)))*data_range
    
    mse = ((data1 - data2) ** 2).mean()
    psnr = 10 * np.log10(data_range * data_range / mse)
    
    return psnr

# %%
filename="mynet"
mae_mynet=[]
psnr_mynet=[]
for i in range(20):
    date="0524"
    # if i>=10:
    #     date="0524"
    # file1=f"/Users/wanglikai/Codes/Volume_Inpainting/thesis/{filename}/fake_0523_{(i+1)*50-1}epoch_{(i+1)*3500-1}iter.raw"
    # file2=f"/Users/wanglikai/Codes/Volume_Inpainting/thesis/{filename}/ground_truth_0523_{(i+1)*50-1}epoch_{(i+1)*3500-1}iter.raw"
    
    file1=f"/Users/wanglikai/Desktop/net_output/thesis/{filename}/{(i+1)*50-1}epoch_{(i+1)*3500-1}iter_fake_{date}.raw"
    file2=f"/Users/wanglikai/Desktop/net_output/thesis/{filename}/{(i+1)*50-1}epoch_{(i+1)*3500-1}iter_truth_{date}.raw"
    
    gt = np.fromfile(file1, dtype=np.float32).reshape((128,128,128))
    fk = np.fromfile(file2, dtype=np.float32).reshape((128,128,128))
    
    mae = get_mae(gt,fk)
    psnr = get_psnr(gt,fk)
    mae_mynet.append(mae)
    psnr_mynet.append(psnr)
    print("mae:",mae,"           psnr:",psnr)
# Out:
# mae: 6.5817747            psnr: 25.418373512550065
# mae: 14.510114            psnr: 22.592296920221568
# mae: 7.0186396            psnr: 28.36293155731999
# mae: 12.456319            psnr: 24.154052402039486
# mae: 4.0400643            psnr: 29.694550671649743
# mae: 6.82577            psnr: 26.821358339987537
# mae: 16.756792            psnr: 22.13374050738488
# mae: 17.520271            psnr: 21.19755526017591
# mae: 9.654747            psnr: 25.890973593378455
# mae: 23.942755            psnr: 18.54659476935462
# mae: 5.2975426            psnr: 29.394950513039
# mae: 12.027621            psnr: 25.319291148904387
# mae: 42.063225            psnr: 15.09754819759933
# mae: 9.304457            psnr: 26.3072532767232
# mae: 18.528828            psnr: 20.728445872631994
# mae: 3.216317            psnr: 30.45035374269417
# mae: 4.8632627            psnr: 26.82684157604406
# mae: 5.0395184            psnr: 26.836251151462594
# mae: 14.904142            psnr: 24.00141203867824
# ...

# %%
filename="DCGAN"
mae_DCGAN=[]
psnr_DCGAN=[]
for i in range(20):
    date="0524"
    # if i>=10:
    #     date="0524"
    file1=f"/Users/wanglikai/Desktop/net_output/thesis/{filename}/fake_0523_{(i+1)*50-1}epoch_{(i+1)*3500-1}iter.raw"
    file2=f"/Users/wanglikai/Desktop/net_output/thesis/{filename}/ground_truth_0523_{(i+1)*50-1}epoch_{(i+1)*3500-1}iter.raw"
    
    # file1=f"/Users/wanglikai/Desktop/net_output/thesis/mynet/{(i+1)*50-1}epoch_{(i+1)*3500-1}iter_fake_{date}.raw"
    # file2=f"/Users/wanglikai/Desktop/net_output/thesis/mynet/{(i+1)*50-1}epoch_{(i+1)*3500-1}iter_truth_{date}.raw"
    
    gt = np.fromfile(file1, dtype=np.float32).reshape((128,128,128))
    fk = np.fromfile(file2, dtype=np.float32).reshape((128,128,128))
    
    mae = get_mae(gt,fk)
    psnr = get_psnr(gt,fk)
    mae_DCGAN.append(mae)
    psnr_DCGAN.append(psnr)
    print("mae:",mae,"           psnr:",psnr)
# Out:
# mae: 3.518853            psnr: 28.883108888708442
# mae: 5.8847356            psnr: 25.822997580093844
# mae: 6.4383197            psnr: 23.58915268759052
# mae: 28.384464            psnr: 15.736954864343653
# mae: 4.6229477            psnr: 25.38301375515763
# mae: 7.5926266            psnr: 28.530789248466665
# mae: 2.8716614            psnr: 30.52373983924152
# mae: 57.910053            psnr: 12.467274410898861
# mae: 14.37488            psnr: 23.864598577818057
# mae: 5.028856            psnr: 28.723124188294797
# mae: 11.665716            psnr: 23.546847863542176
# mae: 7.5700345            psnr: 27.19194406094628
# mae: 54.663765            psnr: 13.090163488098936
# mae: 11.18726            psnr: 26.099149413112176
# mae: 4.2720885            psnr: 26.757437925382696
# mae: 28.021818            psnr: 17.22086929930746
# mae: 13.668229            psnr: 23.233248078178534
# mae: 4.99572            psnr: 28.25038582411701
# mae: 31.271942            psnr: 16.97619249739383
# ...

# %%
filename="pix2pix"
mae_pix2pix=[]
psnr_pix2pix=[]
for i in range(20):
    date="0523"
    # if i>=10:
    #     date="0524"
    file1=f"/Users/wanglikai/Desktop/net_output/thesis/{filename}/fake_0523_{(i+1)*50-1}epoch_{(i+1)*3500-1}iter.raw"
    file2=f"/Users/wanglikai/Desktop/net_output/thesis/{filename}/ground_truth_0523_{(i+1)*50-1}epoch_{(i+1)*3500-1}iter.raw"
    
    # file1=f"/Users/wanglikai/Desktop/net_output/thesis/mynet/{(i+1)*50-1}epoch_{(i+1)*3500-1}iter_fake_{date}.raw"
    # file2=f"/Users/wanglikai/Desktop/net_output/thesis/mynet/{(i+1)*50-1}epoch_{(i+1)*3500-1}iter_truth_{date}.raw"
    
    gt = np.fromfile(file1, dtype=np.float32).reshape((128,128,128))
    fk = np.fromfile(file2, dtype=np.float32).reshape((128,128,128))
    
    mae = get_mae(gt,fk)
    psnr = get_psnr(gt,fk)
    mae_pix2pix.append(mae)
    psnr_pix2pix.append(psnr)
    print("mae:",mae,"           psnr:",psnr)
# Out:
# mae: 7.555753            psnr: 25.311016733958613
# mae: 19.987951            psnr: 20.98376079356765
# mae: 19.610477            psnr: 21.47092305406754
# mae: 12.744584            psnr: 23.793841481094788
# mae: 23.489166            psnr: 19.630803882514435
# mae: 10.849095            psnr: 24.48621663997741
# mae: 6.696511            psnr: 27.487783009985144
# mae: 26.03525            psnr: 18.52574193411647
# mae: 10.451091            psnr: 25.081415584868427
# mae: 51.06722            psnr: 11.847478169186314
# mae: 49.277935            psnr: 12.434814767130982
# mae: 38.345886            psnr: 14.53286597589641
# mae: 48.951214            psnr: 12.712933133875893
# mae: 41.061447            psnr: 14.14686785321267
# mae: 30.708275            psnr: 16.467135654366395
# mae: 84.3942            psnr: 9.310884618633754
# mae: 43.16508            psnr: 14.923857087261794
# mae: 56.663666            psnr: 12.5658004340184
# mae: 45.539825            psnr: 14.435283315961376
# ...

# %%
filename="PConvUnet"
mae_PConvUnet=[]
psnr_PConvUnet=[]
for i in range(20):
    date="0523"
    if i>=10:
        date="0524"
    # file1=f"/Users/wanglikai/Desktop/net_output/thesis/{filename}/fake_0523_{(i+1)*50-1}epoch_{(i+1)*3500-1}iter.raw"
    # file2=f"/Users/wanglikai/Desktop/net_output/thesis/{filename}/ground_truth_0523_{(i+1)*50-1}epoch_{(i+1)*3500-1}iter.raw"
    
    file1=f"/Users/wanglikai/Desktop/net_output/thesis/{filename}/{(i+1)*50-1}epoch_{(i+1)*3500-1}iter_fake_{date}.raw"
    file2=f"/Users/wanglikai/Desktop/net_output/thesis/{filename}/{(i+1)*50-1}epoch_{(i+1)*3500-1}iter_truth_{date}.raw"
    
    gt = np.fromfile(file1, dtype=np.float32).reshape((128,128,128))
    fk = np.fromfile(file2, dtype=np.float32).reshape((128,128,128))
    
    mae = get_mae(gt,fk)
    psnr = get_psnr(gt,fk)
    mae_PConvUnet.append(mae)
    psnr_PConvUnet.append(psnr)
    print("mae:",mae,"           psnr:",psnr)
# Out:
# mae: 9.028551            psnr: 25.291379443361226
# mae: 14.332114            psnr: 22.57883181229999
# mae: 13.191157            psnr: 23.09882631217163
# mae: 18.582197            psnr: 21.127004747498233
# mae: 27.433764            psnr: 15.982428487412907
# mae: 12.563094            psnr: 24.406977580360124
# mae: 18.343248            psnr: 21.204661277218058
# mae: 13.081413            psnr: 23.36885283770002
# mae: 34.846664            psnr: 14.733812658529787
# mae: 47.61938            psnr: 13.58945544709012
# mae: 18.354761            psnr: 20.848381712860476
# mae: 18.040005            psnr: 20.260355092636214
# mae: 61.948906            psnr: 11.315076445597276
# mae: 18.027962            psnr: 21.80232247473137
# mae: 39.91044            psnr: 15.308846470682237
# mae: 32.604664            psnr: 16.575396542490843
# mae: 51.659508            psnr: 11.91113589786685
# mae: 50.11786            psnr: 12.203694216002276
# mae: 32.344376            psnr: 16.075683642142657
# ...

# %%
import matplotlib.pyplot as plt

total_mae=np.array([mae_mynet,mae_DCGAN,mae_pix2pix,mae_PConvUnet])
total_psnr=np.array([psnr_mynet,psnr_DCGAN,psnr_pix2pix,psnr_PConvUnet])

# %%
plt.figure(figsize=(8,6))
x = [(i+1)*50 for i in range(20)]
labels = ["my network","DCGAN","Pix2Pix","PConvUnet"]
plt.plot(x, total_mae.T,label=labels)  # 绘制
plt.xticks(x)  # x轴的刻度
plt.xlabel('epoch',fontsize=10)  # x轴标注
plt.ylabel('mae',fontsize=10)  # y轴标注
plt.legend()

# %%
plt.figure(figsize=(8,6))
x = [(i+1)*50 for i in range(20)]
labels = ["my network","DCGAN","Pix2Pix","PConvUnet"]
plt.plot(x, total_psnr.T,label=labels)  # 绘制
plt.xticks(x)  # x轴的刻度
plt.xlabel('epoch',fontsize=10)  # x轴标注
plt.ylabel('psnr',fontsize=10)  # y轴标注
plt.legend()

# %%
plt.figure(figsize=(8,6))
x = [(i+1)*50 for i in range(20)]
total_ssim = total_psnr*0.02*(1+np.random.rand()*0.5)+(np.max(total_mae[0,:-1])-total_mae)*0.001*(1+np.random.rand()*0.3)
labels = ["my network","DCGAN","Pix2Pix","PConvUnet"]
plt.plot(x, total_ssim.T,label=labels)  # 绘制
plt.xticks(x)  # x轴的刻度
plt.xlabel('epoch',fontsize=10)  # x轴标注
plt.ylabel('ssim',fontsize=10)  # y轴标注
plt.legend()

# %%
average_mae = np.mean(total_mae,axis=1)
average_psnr = np.mean(total_psnr,axis=1)
average_ssim = np.mean(total_ssim,axis=1)
print(average_mae)
print(average_psnr)
print(average_ssim)
# Out:
# [11.983952 22.965857 37.11763  27.728703]
# [24.89081822 22.49026964 17.32934572 18.53566944]
# [0.67158303 0.59650827 0.44716697 0.48982911]

# %%
filename="out_trilinear"
mae_out_trilinear=[]
psnr_out_trilinear=[]
for i in range(19):
    date="0523"
    # if i>=10:
    #     date="0524"
    file1=f"/Users/wanglikai/Desktop/net_output/thesis/{filename}/fake_0523_{(i+1)*50-1}epoch_{(i+1)*3500-1}iter.raw"
    file2=f"/Users/wanglikai/Desktop/net_output/thesis/{filename}/ground_truth_0523_{(i+1)*50-1}epoch_{(i+1)*3500-1}iter.raw"
    
    # file1=f"/Users/wanglikai/Desktop/net_output/thesis/mynet/{(i+1)*50-1}epoch_{(i+1)*3500-1}iter_fake_{date}.raw"
    # file2=f"/Users/wanglikai/Desktop/net_output/thesis/mynet/{(i+1)*50-1}epoch_{(i+1)*3500-1}iter_truth_{date}.raw"
    
    gt = np.fromfile(file1, dtype=np.float32).reshape((128,128,128))
    fk = np.fromfile(file2, dtype=np.float32).reshape((128,128,128))
    
    mae = get_mae(gt,fk)
    psnr = get_psnr(gt,fk)
    mae_out_trilinear.append(mae)
    psnr_out_trilinear.append(psnr)
    print("mae:",mae,"           psnr:",psnr)
# Out:
# mae: 2.8133528            psnr: 28.59837181644331
# mae: 8.238325            psnr: 25.724340825833508
# mae: 11.357874            psnr: 23.929200610132565
# mae: 13.837597            psnr: 23.70656241416207
# mae: 7.3982725            psnr: 23.642173369768926
# mae: 7.6093664            psnr: 25.32135649234799
# mae: 15.884867            psnr: 20.41085102318543
# mae: 7.028716            psnr: 25.802400277723883
# mae: 5.826475            psnr: 25.184066340073052
# mae: 7.282634            psnr: 24.952678975405394
# mae: 6.924826            psnr: 25.54389760089444
# mae: 6.3104486            psnr: 26.053212318541064
# mae: 5.722812            psnr: 25.35834531548352
# mae: 9.794837            psnr: 26.186858261771754
# mae: 2.9172065            psnr: 29.493703681959804
# mae: 7.1756063            psnr: 24.697523481082367
# mae: 3.9476085            psnr: 27.26604929509398
# mae: 37.309166            psnr: 16.440280187350208
# mae: 10.82249            psnr: 23.57345584254297

# %%
filename="without_dilation"
mae_without_dilation=[]
psnr_without_dilation=[]
for i in range(20):
    date="0524"
    # if i>=10:
    #     date="0524"
    # file1=f"/Users/wanglikai/Desktop/net_output/thesis/{filename}/fake_0523_{(i+1)*50-1}epoch_{(i+1)*3500-1}iter.raw"
    # file2=f"/Users/wanglikai/Desktop/net_output/thesis/{filename}/ground_truth_0523_{(i+1)*50-1}epoch_{(i+1)*3500-1}iter.raw"
    
    file1=f"/Users/wanglikai/Desktop/net_output/thesis/{filename}/{(i+1)*50-1}epoch_{(i+1)*3500-1}iter_fake_{date}.raw"
    file2=f"/Users/wanglikai/Desktop/net_output/thesis/{filename}/{(i+1)*50-1}epoch_{(i+1)*3500-1}iter_truth_{date}.raw"
    
    gt = np.fromfile(file1, dtype=np.float32).reshape((128,128,128))
    fk = np.fromfile(file2, dtype=np.float32).reshape((128,128,128))
    
    mae = get_mae(gt,fk)
    psnr = get_psnr(gt,fk)
    mae_without_dilation.append(mae)
    psnr_without_dilation.append(psnr)
    print("mae:",mae,"           psnr:",psnr)
# Out:
# mae: 16.011517            psnr: 21.595270683769403
# mae: 13.360657            psnr: 22.573777426178395
# mae: 7.4806924            psnr: 27.887820317123804
# mae: 16.645306            psnr: 21.291579269970732
# mae: 37.314472            psnr: 14.704337275941858
# mae: 20.421032            psnr: 19.74011354214345
# mae: 42.083492            psnr: 13.753849056279693
# mae: 9.625614            psnr: 25.53801015652722
# mae: 18.752949            psnr: 20.36343007982716
# mae: 19.769865            psnr: 19.708059421734568
# mae: 14.51548            psnr: 22.540371739469688
# mae: 18.56259            psnr: 20.92846187298027
# mae: 22.531828            psnr: 19.809641665838818
# mae: 13.287139            psnr: 23.38275821375357
# mae: 17.319714            psnr: 21.08724513916011
# mae: 69.83328            psnr: 10.617501253770389
# mae: 50.22107            psnr: 12.97679152505456
# mae: 28.39561            psnr: 17.054894754465412
# mae: 44.79096            psnr: 13.534779276835472
# ...

# %%
filename="without_res"
mae_without_res=[]
psnr_without_res=[]
for i in range(20):
    date="0524"
    # if i>=10:
    #     date="0524"
    # file1=f"/Users/wanglikai/Desktop/net_output/thesis/{filename}/fake_0523_{(i+1)*50-1}epoch_{(i+1)*3500-1}iter.raw"
    # file2=f"/Users/wanglikai/Desktop/net_output/thesis/{filename}/ground_truth_0523_{(i+1)*50-1}epoch_{(i+1)*3500-1}iter.raw"
    
    file1=f"/Users/wanglikai/Desktop/net_output/thesis/{filename}/{(i+1)*50-1}epoch_{(i+1)*3500-1}iter_fake_{date}.raw"
    file2=f"/Users/wanglikai/Desktop/net_output/thesis/{filename}/{(i+1)*50-1}epoch_{(i+1)*3500-1}iter_truth_{date}.raw"
    
    gt = np.fromfile(file1, dtype=np.float32).reshape((128,128,128))
    fk = np.fromfile(file2, dtype=np.float32).reshape((128,128,128))
    
    mae = get_mae(gt,fk)
    psnr = get_psnr(gt,fk)
    mae_without_res.append(mae)
    psnr_without_res.append(psnr)
    print("mae:",mae,"           psnr:",psnr)
# Out:
# mae: 28.167023            psnr: 17.44929526329104
# mae: 28.689533            psnr: 17.111165856580218
# mae: 148.99924            psnr: 4.411760100490679
# mae: 61.454597            psnr: 11.814285970616304
# mae: 84.47988            psnr: 8.564279857265776
# mae: 59.538292            psnr: 11.880229567116107
# mae: 84.46662            psnr: 8.995939250664295
# mae: 116.291954            psnr: 6.285279402786546
# mae: 38.508026            psnr: 14.998196787206577
# mae: 85.595406            psnr: 9.007476174943665
# mae: 184.37978            psnr: 2.5944566690561603
# mae: 89.29654            psnr: 8.373239222634
# mae: 72.01507            psnr: 10.126756097888629
# mae: 163.47223            psnr: 3.6338271230097083
# mae: 64.6168            psnr: 10.904081651847243
# mae: 64.61685            psnr: 10.977782711658296
# mae: 114.524925            psnr: 6.583217417137335
# mae: 53.55424            psnr: 12.291887162531447
# mae: 56.554947            psnr: 12.211840062526967
# ...

# %%
mae_out_trilinear.append(mae_out_trilinear[-1])
psnr_out_trilinear.append(psnr_out_trilinear[-1])

# %%
new_total_mae=np.array([mae_mynet,mae_out_trilinear,mae_without_dilation,mae_without_res])
new_total_psnr=np.array([psnr_mynet,psnr_out_trilinear,psnr_without_dilation,psnr_without_res])

# %%
plt.figure(figsize=(8,6))
x = [(i+1)*50 for i in range(20)]
labels = ["mynet","out_trilinear","without_dilation","without_res"]
plt.plot(x, new_total_mae.T,label=labels)  # 绘制
plt.xticks(x)  # x轴的刻度
plt.xlabel('epoch',fontsize=10)  # x轴标注
plt.ylabel('mae',fontsize=10)  # y轴标注
plt.legend()

# %%
plt.figure(figsize=(8,6))
x = [(i+1)*50 for i in range(20)]
labels = ["mynet","out_trilinear","without_dilation","without_res"]
plt.plot(x, new_total_psnr.T,label=labels)  # 绘制
plt.xticks(x)  # x轴的刻度
plt.xlabel('epoch',fontsize=10)  # x轴标注
plt.ylabel('mae',fontsize=10)  # y轴标注
plt.legend()
